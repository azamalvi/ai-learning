# %% [markdown]
# import numpy as np
# import pandas as pd
#
# data = np.random.randint(1, 50, size=6)
# df = pd.DataFrame(data, columns=["Random"])
# print("Min:", df['Random'].min())
# print("Mean:", df['Random'].mean())
# print("Max:", df['Random'].max())
# df['Squares'] = np.square(df['Random'])
# print(np.random.randint(1, 101, size=10))
# print(np.random.rand(10))

# %% [markdown]
# # To use differe
